# %%
import pandas as pd

food_df = pd.read_csv(r"C:\Users\DELL\nephrocare\data\processed\ifct2017_ckd_foods.csv")

print("Dataset Shape:", food_df.shape)

print("\nColumns:")
print(food_df.columns.tolist())

food_df.head()

import pandas as pd

food_df = pd.read_csv(r"C:\Users\DELL\nephrocare\data\processed\ifct2017_ckd_foods.csv")

print("Dataset Shape:", food_df.shape)

print("\nColumns:")
print(food_df.columns.tolist())

food_df.head()
# Out:
# Dataset Shape: (527, 7)
#
# Columns:
# ['food_name', 'category', 'protein_g', 'energy_kcal', 'potassium_mg', 'phosphorus_mg', 'sodium_mg']
# Dataset Shape: (527, 7)
#
# Columns:
# ['food_name', 'category', 'protein_g', 'energy_kcal', 'potassium_mg', 'phosphorus_mg', 'sodium_mg']
#                                          food_name             category  \
# 0       Amaranth seed, black (Amaranthus cruentus)  Cereals and millets
# 1  Amaranth seed, pale brown (Amaranthus cruentus)  Cereals and millets
# 2                    Bajra (Pennisetum typhoideum)  Cereals and millets
# 3                         Barley (Hordeum vulgare)  Cereals and millets
# 4                          Jowar (Sorghum vulgare)  Cereals and millets
#
#    protein_g  energy_kcal  potassium_mg  phosphorus_mg  sodium_mg
# 0      14.59       356.12         433.0          374.0       2.70
# 1      13.27       355.88         413.0          412.0       2.81
# ...

# %%
# Add CKD safety category for every food

def classify_food(row):

    if (
        row["potassium_mg"] <= 200 and
        row["phosphorus_mg"] <= 150 and
        row["sodium_mg"] <= 140
    ):
        return "Safe"

    elif (
        row["potassium_mg"] <= 350 and
        row["phosphorus_mg"] <= 250 and
        row["sodium_mg"] <= 300
    ):
        return "Moderate"

    else:
        return "Avoid"


food_df["safety"] = food_df.apply(
    classify_food,
    axis=1
)

food_df["safety"].value_counts()
# Out:
# safety
# Avoid       226
# Moderate    221
# Safe         80
# Name: count, dtype: int64

# %%
food_df["safety"].value_counts().plot(
    kind="bar"
)
# Out:
# <Axes: xlabel='safety'>

# %%
# Recommend foods based on CKD stage

def recommend_foods(stage, top_n=20):

    if stage >= 4:

        recommendations = food_df[
            food_df["safety"] == "Safe"
        ]

    else:

        recommendations = food_df[
            food_df["safety"].isin(
                ["Safe", "Moderate"]
            )
        ]

    recommendations = recommendations.sort_values(
        by=[
            "potassium_mg",
            "phosphorus_mg",
            "sodium_mg"
        ]
    )

    return recommendations.head(top_n)

# %%
stage5_foods = recommend_foods(
    stage=5
)

stage5_foods[
    [
        "food_name",
        "category",
        "protein_g",
        "potassium_mg",
        "phosphorus_mg",
        "sodium_mg",
        "safety"
    ]
]
# Out:
#                                              food_name  \
# 355                                        Goat, tripe
# 203                   Mangosteen (Garcinia mangostana)
# 368                                       Sheep, tripe
# 155           Tinda, tender (Praecitrullus fistulosus)
# 307                       Toddy (Borassus flabellifer)
# 154         Snake gourd, short (Trichosanthes anguina)
# 16                     Varagu (Paspalum scrobiculatum)
# 162                     Apple, green (Malus domestica)
# 166              Apricot, processed (Prunus armeniaca)
# 163                     Apple, small (Malus domestica)
# 152  Snake gourd, long, pale green (Trichosanthes a...
# 191          Jambu fruit, ripe (Syzygium samarangense)
# 153  Snake gourd, long, dark green (Trichosanthes a...
# 15                             Samai (Panicum miliare)
# 210                                   Pear (Pyrus sp.)
# 164            Apple, small, Kashmir (Malus domestica)
# ...

# %%
stage3_foods = recommend_foods(
    stage=3
)

stage3_foods[
    [
        "food_name",
        "category",
        "protein_g",
        "potassium_mg",
        "phosphorus_mg",
        "sodium_mg",
        "safety"
    ]
]
# Out:
#                                              food_name  \
# 355                                        Goat, tripe
# 203                   Mangosteen (Garcinia mangostana)
# 368                                       Sheep, tripe
# 155           Tinda, tender (Praecitrullus fistulosus)
# 307                       Toddy (Borassus flabellifer)
# 154         Snake gourd, short (Trichosanthes anguina)
# 16                     Varagu (Paspalum scrobiculatum)
# 162                     Apple, green (Malus domestica)
# 166              Apricot, processed (Prunus armeniaca)
# 163                     Apple, small (Malus domestica)
# 152  Snake gourd, long, pale green (Trichosanthes a...
# 191          Jambu fruit, ripe (Syzygium samarangense)
# 153  Snake gourd, long, dark green (Trichosanthes a...
# 15                             Samai (Panicum miliare)
# 210                                   Pear (Pyrus sp.)
# 164            Apple, small, Kashmir (Malus domestica)
# ...

# %%
def search_food(food_name):

    result = food_df[
        food_df["food_name"]
        .str.lower()
        .str.contains(
            food_name.lower(),
            na=False
        )
    ]

    return result[
        [
            "food_name",
            "category",
            "protein_g",
            "energy_kcal",
            "potassium_mg",
            "phosphorus_mg",
            "sodium_mg",
            "safety"
        ]
    ]

# %%
search_food("Rice")
# Out:
#                                  food_name             category  protein_g  \
# 10       Rice flakes (poha) (Oryza sativa)  Cereals and millets       7.44
# 11              Rice puffed (Oryza sativa)  Cereals and millets       7.47
# 12         Rice, raw, brown (Oryza sativa)  Cereals and millets       9.16
# 13  Rice, parboiled, milled (Oryza sativa)  Cereals and millets       7.81
# 14        Rice, raw, milled (Oryza sativa)  Cereals and millets       7.94
# 46              Ricebean (Vigna umbellata)        Grain legumes      19.97
#
#     energy_kcal  potassium_mg  phosphorus_mg  sodium_mg    safety
# 10       353.73         148.0          195.0       2.58  Moderate
# 11       361.85         140.0          152.0       3.69  Moderate
# 12       353.73         199.0          267.0       3.64     Avoid
# 13       351.58         142.0          140.0       3.16      Safe
# 14       356.36         108.0           96.0       2.34      Safe
# ...

# %%
food_df.to_csv(
    "data/processed/indian_ckd_foods.csv",
    index=False
)

print("Food recommendation dataset saved")
# Out:
# Food recommendation dataset saved

# %%
# Vegetarian / Non-Vegetarian tagging

non_veg_keywords = [
    "fish",
    "chicken",
    "mutton",
    "egg",
    "beef",
    "pork",
    "meat",
    "prawn",
    "shrimp"
]

def get_diet_type(food):

    food = str(food).lower()

    for keyword in non_veg_keywords:
        if keyword in food:
            return "Non-Vegetarian"

    return "Vegetarian"

food_df["diet_type"] = food_df["food_name"].apply(
    get_diet_type
)

food_df["diet_type"].value_counts()
# Out:
# diet_type
# Vegetarian        459
# Non-Vegetarian     68
# Name: count, dtype: int64

# %%
# Personalized recommendations

def recommend_foods_v2(
    stage,
    diet_type="Vegetarian",
    min_protein=0,
    top_n=20
):

    data = food_df.copy()

    if stage >= 4:

        data = data[
            data["safety"] == "Safe"
        ]

    else:

        data = data[
            data["safety"].isin(
                ["Safe", "Moderate"]
            )
        ]

    data = data[
        data["diet_type"] == diet_type
    ]

    data = data[
        data["protein_g"] >= min_protein
    ]

    score = (
        data["protein_g"] * 2
        - data["potassium_mg"] * 0.01
        - data["phosphorus_mg"] * 0.01
        - data["sodium_mg"] * 0.01
    )

    data["recommendation_score"] = score

    data = data.sort_values(
        by="recommendation_score",
        ascending=False
    )

    return data.head(top_n)

# %%
recommend_foods_v2(
    stage=5,
    diet_type="Vegetarian",
    min_protein=5,
    top_n=15
)[
    [
        "food_name",
        "protein_g",
        "potassium_mg",
        "phosphorus_mg",
        "sodium_mg",
        "recommendation_score"
    ]
]
# Out:
#                                           food_name  protein_g  potassium_mg  \
# 368                                    Sheep, tripe      16.76         48.75
# 355                                     Goat, tripe      15.36         45.00
# 358                    Goat, tube (small intestine)      12.92        130.00
# 17         Wheat flour, refined (Triticum aestivum)      10.36        148.00
# 23   Wheat, vermicelli, roasted (Triticum aestivum)      10.37        177.00
# 15                          Samai (Panicum miliare)      10.13        105.00
# 22            Wheat, vermicelli (Triticum aestivum)       9.70        163.00
# 16                  Varagu (Paspalum scrobiculatum)       8.92         94.00
# 14                 Rice, raw, milled (Oryza sativa)       7.94        108.00
# 13           Rice, parboiled, milled (Oryza sativa)       7.81        142.00
#
#      phosphorus_mg  sodium_mg  recommendation_score
# 368          55.61      18.37               32.2927
# ...

# %%
high_protein = food_df.sort_values(
    by="protein_g",
    ascending=False
)

high_protein[
    [
        "food_name",
        "protein_g",
        "safety"
    ]
].head(20)
# Out:
#                                        food_name  protein_g    safety
# 48                  Soybean, white (Glycine max)      37.80     Avoid
# 47                  Soybean, brown (Glycine max)      35.58     Avoid
# 272  Fenugreek seeds (Trigonella foenum graecum)      25.41     Avoid
# 501           Eggs, Cat fish (Ompok bimaculatus)      24.68     Avoid
# 493                     Tuna (Euthynnus affinis)      24.50     Avoid
# 36                   Lentil dal (Lens culinaris)      24.35     Avoid
# 489                Stingray (Dasyatis pastinaca)      23.98  Moderate
# 33               Green gram, dal (Vigna radiata)      23.88     Avoid
# 440                       Korka (Terapon jarbua)      23.72  Moderate
# 446                    Milk fish (Chanos chanos)      23.66     Avoid
# 291                Ground nut (Arachis hypogaea)      23.65     Avoid
# 299          Sunflower seeds (Helianthus annuus)      23.53     Avoid
# ...

# %%
# category wise food
food_df["category"].value_counts().head(20)
# Out:
# category
# Marine fish                      92
# Other vegetables                 78
# Fruits                           67
# Animal meat                      63
# Green leafy vegetables           34
# Condiments and spices            33
# Grain legumes                    25
# Cereals and millets              24
# Nuts and oil seeds               21
# Roots and tubers                 19
# Poultry                          19
# Egg and egg products             15
# Freshwater fish and shellfish    10
# Marine shellfish                  8
# Marine mollusks                   7
# Mushrooms                         4
# Milk and milk products            4
# Miscellaneous foods               2
# Sugars                            2
# Name: count, dtype: int64

# %%
def recommend_by_category(
    category,
    stage=5,
    top_n=10
):

    foods = recommend_foods_v2(
        stage=stage,
        top_n=100
    )

    foods = foods[
        foods["category"]
        .str.contains(
            category,
            case=False,
            na=False
        )
    ]

    return foods.head(top_n)

# %%
recommend_by_category(
    "Vegetables",
    stage=5
)
# Out:
#                                              food_name  \
# 85          Bean scarlet, tender (Phaseolus coccineus)
# 71              Gogu leaves, red (Hibiscus cannabinus)
# 142                      Parwar (Trichosanthes dioica)
# 160                  Zucchini, yellow (Cucurbita pepo)
# 155           Tinda, tender (Praecitrullus fistulosus)
# 152  Snake gourd, long, pale green (Trichosanthes a...
# 94                       Brinjal-3 (Solanum melongena)
# 137                 Kovai, small (Coccinia cordifolia)
# 115                  Capsicum, green (Capsicum annuum)
# 136                   Kovai, big (Coccinia cordifolia)
#
#                    category  protein_g  energy_kcal  potassium_mg  \
# 85         Other vegetables       2.86        42.78        164.00
# 71   Green leafy vegetables       1.85        36.57        161.00
# 142        Other vegetables       1.40        24.14        117.00
# 160        Other vegetables       1.31        18.88        131.00
# ...

# %%
def calculate_food_score(row):

    score = 100

    score -= row["potassium_mg"] * 0.05
    score -= row["phosphorus_mg"] * 0.05
    score -= row["sodium_mg"] * 0.05

    score += row["protein_g"] * 1

    return max(0, min(100, score))


food_df["kidney_score"] = food_df.apply(
    calculate_food_score,
    axis=1
)

food_df[
    [
        "food_name",
        "kidney_score"
    ]
].head()
# Out:
#                                          food_name  kidney_score
# 0       Amaranth seed, black (Amaranthus cruentus)       74.1050
# 1  Amaranth seed, pale brown (Amaranthus cruentus)       71.8795
# 2                    Bajra (Pennisetum typhoideum)       78.0545
# 3                         Barley (Hordeum vulgare)       88.2620
# 4                          Jowar (Sorghum vulgare)       79.5990

# %%
# Top Kidney Friendly Foods
food_df.sort_values(
    by="kidney_score",
    ascending=False
)[
    [
        "food_name",
        "category",
        "kidney_score",
        "safety"
    ]
].head(25)
# Out:
#                                      food_name                category  \
# 485                   Silan (Silonia silondia)             Marine fish
# 447                  Moon fish (Mene maculata)             Marine fish
# 358               Goat, tube (small intestine)             Animal meat
# 355                                Goat, tripe             Animal meat
# 379                                Beef, tripe             Animal meat
# 368                               Sheep, tripe             Animal meat
# 488               Sole fish (Cynoglossus arel)             Marine fish
# 16             Varagu (Paspalum scrobiculatum)     Cereals and millets
# 487  Silver carp (Hypophthalmichthys molitrix)             Marine fish
# 403               Pork, tube (small intestine)             Animal meat
# 489              Stingray (Dasyatis pastinaca)             Marine fish
# 311                                     Paneer  Milk and milk products
# ...

# %%
# Save Final Engine Dataset
food_df.to_csv(
    "data/processed/final_food_recommendation_engine.csv",
    index=False
)

print("Food recommendation engine ready")
# Out:
# Food recommendation engine ready

# %%
# CKD nutrition limits by stage

ckd_limits = {

    1: {
        "max_potassium": 3500,
        "max_phosphorus": 1400,
        "max_sodium": 2300
    },

    2: {
        "max_potassium": 3000,
        "max_phosphorus": 1200,
        "max_sodium": 2000
    },

    3: {
        "max_potassium": 2000,
        "max_phosphorus": 1000,
        "max_sodium": 1500
    },

    4: {
        "max_potassium": 1800,
        "max_phosphorus": 900,
        "max_sodium": 1200
    },

    5: {
        "max_potassium": 1500,
        "max_phosphorus": 800,
        "max_sodium": 1000
    }
}

# %%
# Create food groups for meal planning

def get_food_group(category):

    category = str(category).lower()

    if category in [
        "cereals and millets",
        "roots and tubers"
    ]:
        return "Carbs"

    elif category in [
        "grain legumes",
        "milk and milk products",
        "egg and egg products"
    ]:
        return "Protein"

    elif category in [
        "other vegetables",
        "green leafy vegetables",
        "mushrooms"
    ]:
        return "Vegetable"

    elif category == "fruits":
        return "Fruit"

    else:
        return "Other"


food_df["food_group"] = food_df["category"].apply(
    get_food_group
)

food_df["food_group"].value_counts()
# Out:
# food_group
# Other        257
# Vegetable    116
# Fruit         67
# Protein       44
# Carbs         43
# Name: count, dtype: int64

# %%
# Remove foods that don't belong in meal plans

bad_keywords = [
    "tripe",
    "intestine",
    "tube",
    "shellfish",
    "mollusk"
]

food_df = food_df[
    ~food_df["food_name"]
    .str.lower()
    .str.contains(
        "|".join(bad_keywords),
        na=False
    )
]

# %%
def generate_meal_plan(
    calorie_target,
    ckd_stage=3
):

    limits = ckd_limits[ckd_stage]

    foods = food_df.copy()

    foods = foods[
        foods["potassium_mg"]
        <= limits["max_potassium"] / 4
    ]

    foods = foods[
        foods["phosphorus_mg"]
        <= limits["max_phosphorus"] / 4
    ]

    foods = foods[
        foods["sodium_mg"]
        <= limits["max_sodium"] / 4
    ]

    foods = foods.sort_values(
        by="kidney_score",
        ascending=False
    )

    breakfast = []
    lunch = []
    dinner = []

    used_foods = set()

    def get_food(group):

        candidates = foods[
            (foods["food_group"] == group)
            &
            (~foods["food_name"].isin(
                used_foods
            ))
        ]

        if len(candidates) == 0:
            return None

        food = candidates.iloc[0]

        used_foods.add(
            food["food_name"]
        )

        return food

    # Breakfast

    breakfast.extend([
        get_food("Carbs"),
        get_food("Fruit")
    ])

    # Lunch

    lunch.extend([
        get_food("Carbs"),
        get_food("Vegetable"),
        get_food("Protein")
    ])

    # Dinner

    dinner.extend([
        get_food("Carbs"),
        get_food("Vegetable"),
        get_food("Fruit")
    ])

    breakfast = [
        x for x in breakfast
        if x is not None
    ]

    lunch = [
        x for x in lunch
        if x is not None
    ]

    dinner = [
        x for x in dinner
        if x is not None
    ]

    return {
        "Breakfast": breakfast,
        "Lunch": lunch,
        "Dinner": dinner,
        "Target Calories": calorie_target
    }

# %%
def meal_nutrition(plan):

    selected_foods = []

    for meal_name in [
        "Breakfast",
        "Lunch",
        "Dinner"
    ]:

        foods = plan[meal_name]

        for food in foods:

            selected_foods.append(
                food["food_name"]
            )

    selected_df = food_df[
        food_df["food_name"].isin(
            selected_foods
        )
    ]

    return pd.DataFrame({

        "Target Calories":[
            plan["Target Calories"]
        ],

        "Actual Calories":[
            round(
                selected_df["energy_kcal"].sum(),
                2
            )
        ],

        "Protein_g":[
            round(
                selected_df["protein_g"].sum(),
                2
            )
        ],

        "Potassium_mg":[
            round(
                selected_df["potassium_mg"].sum(),
                2
            )
        ],

        "Phosphorus_mg":[
            round(
                selected_df["phosphorus_mg"].sum(),
                2
            )
        ],

        "Sodium_mg":[
            round(
                selected_df["sodium_mg"].sum(),
                2
            )
        ]
    })

# %%
calorie_target = int(
    input("Enter target calories: ")
)

ckd_stage = int(
    input("Enter CKD Stage (1-5): ")
)
# Out:
# Enter target calories:  2000
# Enter CKD Stage (1-5):  3

# %%
plan = generate_meal_plan(
    calorie_target=calorie_target,
    ckd_stage=ckd_stage
)

print("=" * 50)
print("CKD PERSONALIZED MEAL PLAN")
print("=" * 50)

for meal_name in [
    "Breakfast",
    "Lunch",
    "Dinner"
]:

    print(f"\n{meal_name.upper()}")

    for food in plan[meal_name]:

        print(
            "•",
            food["food_name"]
        )
# Out:
# ...
# CKD PERSONALIZED MEAL PLAN
# ...
#
# BREAKFAST
# • Varagu (Paspalum scrobiculatum)
# • Mangosteen (Garcinia mangostana)
#
# LUNCH
# • Samai (Panicum miliare)
# • Tinda, tender (Praecitrullus fistulosus)
# • Egg, poultry, white, boiled
#
# DINNER
# • Rice, raw, milled (Oryza sativa)
# • Snake gourd, short (Trichosanthes anguina)
# • Apple, green (Malus domestica)

# %%
summary = meal_nutrition(plan)

print("\nNUTRITION SUMMARY")

display(summary)
# Out:
# NUTRITION SUMMARY
#    Target Calories  Actual Calories  Protein_g  Potassium_mg  Phosphorus_mg  \
# 0             2000          1218.93      42.01        735.66         416.36
#
#    Sodium_mg
# 0     182.83
