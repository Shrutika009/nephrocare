# %%
import pandas as pd

food_df = pd.read_csv(
    r"C:\Users\DELL\nephrocare\data\processed\ifct2017_ckd_foods.csv"
)

rice_items = food_df[
    food_df["food_name"]
    .str.contains("Rice", case=False, na=False)
]

print(rice_items["food_name"].tolist())
# Out:
# ['Rice flakes (poha) (Oryza sativa)', 'Rice puffed (Oryza sativa)', 'Rice, raw, brown (Oryza sativa)', 'Rice, parboiled, milled (Oryza sativa)', 'Rice, raw, milled (Oryza sativa)', 'Ricebean (Vigna umbellata)']
